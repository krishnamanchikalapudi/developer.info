# %% [markdown]
# # Software versions

# %%
# !echo $PATH
# Out:
# /opt/homebrew/bin:/Users/krishnam/Library/Python/3.12/bin:/Users/krishnam/.rd/bin:/usr/local/bin:/usr/local/sbin:/opt/homebrew/bin::/opt/homebrew/opt/groovy/libexec:/opt/homebrew/opt/openjdk@21/libexec/openjdk.jdk/Contents/Home/::/opt/homebrew/opt/openjdk@21/libexec/openjdk.jdk/Contents/Home//bin:/opt/homebrew/bin:/opt/homebrew/sbin:/usr/local/bin:/System/Cryptexes/App/usr/bin:/usr/bin:/bin:/usr/sbin:/sbin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/local/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/appleinternal/bin:/opt/podman/bin:/Users/krishnam/.rd/bin:/usr/local/bin:/usr/local/sbin:/opt/homebrew/bin::/opt/homebrew/opt/groovy/libexec:/opt/homebrew/opt/openjdk@21/libexec/openjdk.jdk/Contents/Home/::/opt/homebrew/opt/openjdk@21/libexec/openjdk.jdk/Contents/Home//bin:/opt/homebrew/bin:/opt/homebrew/sbin:/usr/local/bin:/System/Cryptexes/App/usr/bin:/usr/bin:/bin:/usr/sbin:/sbin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/local/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/appleinternal/bin:/opt/podman/bin

# %%
# !type -a python
# Out:
# python not found

# %%
# !type -a pip
# Out:
# pip not found

# %%
python3 -m pip install --upgrade pip
# Out:
#   Cell In[26], line 1
#     python3 -m pip install --upgrade pip
#                ^
# SyntaxError: invalid syntax

# %%
import sys
# !{sys.executable} -m pip install -r requirements.txt --break-system-packages --upgrade
# Out:
# Looking in indexes: https://krishnam:****@psazuse.jfrog.io/artifactory/api/pypi/krishnam-pypi-virtual/simple
# Requirement already satisfied: tensorflow in /opt/homebrew/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (2.16.2)
# Collecting tensorflow (from -r requirements.txt (line 1))
#   Downloading https://psazuse.jfrog.io/artifactory/api/pypi/krishnam-pypi-virtual/packages/packages/e0/cb/aab1d277dc1cb45166a1ac857bf535ef322437f4f6fbef55ad6dee31e00d/tensorflow-2.17.0-cp312-cp312-macosx_12_0_arm64.whl (236.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.3/236.3 MB 15.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: tensorflow-datasets in /opt/homebrew/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (4.9.6)
# Requirement already satisfied: tensorboard in /opt/homebrew/lib/python3.12/site-packages (from -r requirements.txt (line 3)) (2.16.2)
# Collecting tensorboard (from -r requirements.txt (line 3))
#   Downloading https://psazuse.jfrog.io/artifactory/api/pypi/krishnam-pypi-virtual/packages/packages/0a/32/2e8545fb0592f33e3aca5951e8b01008b76d61b440658cbdc37b4eaebf0b/tensorboard-2.17.0-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 7.9 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: Pillow in /opt/homebrew/lib/python3.12/site-packages (from -r requirements.txt (line 4)) (10.3.0)
# Collecting Pillow (from -r requirements.txt (line 4))
#   Downloading https://psazuse.jfrog.io/artifactory/api/pypi/krishnam-pypi-virtual/packages/packages/e7/cf/5c558a0f247e0bf9cec92bff9b46ae6474dd736f6d906315e60e4075f737/pillow-10.4.0-cp312-cp312-macosx_11_0_arm64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 7.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: PyYAML in /opt/homebrew/lib/python3.12/site-packages (from -r requirements.txt (line 5)) (6.0.1)
# Requirement already satisfied: numpy in /opt/homebrew/lib/python3.12/site-packages (from -r requirements.txt (line 6)) (1.26.4)
# Collecting numpy (from -r requirements.txt (line 6))
#   Downloading https://psazuse.jfrog.io/artifactory/api/pypi/krishnam-pypi-virtual/packages/packages/c2/da/3d8debb409bc97045b559f408d2b8cefa6a077a73df14dbf4d8780d976b1/numpy-2.0.1-cp312-cp312-macosx_14_0_arm64.whl (5.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 8.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: urllib3 in /opt/homebrew/lib/python3.12/site-packages (from -r requirements.txt (line 7)) (2.2.1)
# Collecting urllib3 (from -r requirements.txt (line 7))
#   Downloading https://psazuse.jfrog.io/artifactory/api/pypi/krishnam-pypi-virtual/packages/packages/ca/1c/89ffc63a9605b583d5df2be791a27bc1a42b7c32bab68d3c8f2f73a98cd4/urllib3-2.2.2-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.4/121.4 kB 9.8 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /opt/homebrew/lib/python3.12/site-packages (from -r requirements.txt (line 8)) (2.2.2)
# Requirement already satisfied: matplotlib in /opt/homebrew/lib/python3.12/site-packages (from -r requirements.txt (line 9)) (3.8.4)
# Collecting matplotlib (from -r requirements.txt (line 9))
#   Downloading https://psazuse.jfrog.io/artifactory/api/pypi/krishnam-pypi-virtual/packages/packages/4c/88/15bbb864b0d871707294ff325f9ffd0dfa486db2637eb34dd5f8dcf5b9bf/matplotlib-3.9.0-cp312-cp312-macosx_11_0_arm64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 8.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: scipy in /opt/homebrew/lib/python3.12/site-packages (from -r requirements.txt (line 10)) (1.13.0)
# Collecting scipy (from -r requirements.txt (line 10))
#   Downloading https://psazuse.jfrog.io/artifactory/api/pypi/krishnam-pypi-virtual/packages/packages/09/70/5e756d3f90fe3fff64d1550db0fa6bb9eb76eedd084c568618f93441f08c/scipy-1.14.0-cp312-cp312-macosx_14_0_arm64.whl (23.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.1/23.1 MB 12.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pylint in /opt/homebrew/lib/python3.12/site-packages (from -r requirements.txt (line 11)) (3.2.6)
# Requirement already satisfied: tensorflow-macos in /opt/homebrew/lib/python3.12/site-packages (from -r requirements.txt (line 12)) (2.16.2)
# ERROR: Ignored the following versions that require a different python version: 1.10.0 Requires-Python <3.12,>=3.8; 1.10.0rc1 Requires-Python <3.12,>=3.8; 1.10.0rc2 Requires-Python <3.12,>=3.8; 1.10.1 Requires-Python <3.12,>=3.8; 1.21.2 Requires-Python >=3.7,<3.11; 1.21.3 Requires-Python >=3.7,<3.11; 1.21.4 Requires-Python >=3.7,<3.11; 1.21.5 Requires-Python >=3.7,<3.11; 1.21.6 Requires-Python >=3.7,<3.11; 1.6.2 Requires-Python >=3.7,<3.10; 1.6.3 Requires-Python >=3.7,<3.10; 1.7.0 Requires-Python >=3.7,<3.10; 1.7.1 Requires-Python >=3.7,<3.10; 1.7.2 Requires-Python >=3.7,<3.11; 1.7.3 Requires-Python >=3.7,<3.11; 1.8.0 Requires-Python >=3.8,<3.11; 1.8.0rc1 Requires-Python >=3.8,<3.11; 1.8.0rc2 Requires-Python >=3.8,<3.11; 1.8.0rc3 Requires-Python >=3.8,<3.11; 1.8.0rc4 Requires-Python >=3.8,<3.11; 1.8.1 Requires-Python >=3.8,<3.11; 1.9.0 Requires-Python >=3.8,<3.12; 1.9.0rc1 Requires-Python >=3.8,<3.12; 1.9.0rc2 Requires-Python >=3.8,<3.12; 1.9.0rc3 Requires-Python >=3.8,<3.12; 1.9.1 Requires-Python >=3.8,<3.12; 1.9.5 Requires-Python >=2.7, !=3.0.*, !=3.1.*, !=3.2.*, !=3.3.*, <3.7
# ERROR: Could not find a version that satisfies the requirement tensorflow-metal (from versions: none)
# ERROR: No matching distribution found for tensorflow-metal
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python3.12 -m pip install --upgrade pip

# %%
from platform import python_version

print(f"Python version: {python_version()}")
# Out:
# Python version: 3.12.4

# %%
import tensorflow as tf
print(f"TensorFlow version: {tf.__version__}")
# Out:
# TensorFlow version: 2.16.1

# %%
from tensorflow import keras
print(f"keras version: {keras.__version__}")
# Out:
# keras version: 3.3.3

# %%
import matplotlib as mpl
print(f"MatplotLib version: {mpl.__version__}")
# Out:
# MatplotLib version: 3.8.4

# %%
import numpy as np
print(f"Numpy version: {np.__version__}")
# Out:
# Numpy version: 1.26.4

# %%
import pandas as pd
print(f"Pandas version: {pd.__version__}")
# Out:
# Pandas version: 2.2.2

# %% [markdown]
# ## List CPU, GPU, TPU
# - [https://www.tensorflow.org/api_docs/python/tf/config/list_physical_devices](https://www.tensorflow.org/api_docs/python/tf/config/list_physical_devices)
# - [https://www.tensorflow.org/api_docs/python/tf/config/list_logical_devices](https://www.tensorflow.org/api_docs/python/tf/config/list_logical_devices)

# %%
print(f"Num CPUs Available: {len(tf.config.list_physical_devices('CPU'))}")
print(f"Num GPUs Available: {len(tf.config.list_physical_devices('GPU'))}")
print(f"Num TPUs Available: {len(tf.config.list_physical_devices('TPU'))}")
print(f"Available: {tf.config.list_physical_devices()}")
# Out:
# Num CPUs Available: 1
# Num GPUs Available: 0
# Num TPUs Available: 0
# Available: [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %%
tf.config.list_physical_devices("CPU")
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]
